# %% [markdown]
# **IMPORT LIBRARY**

# %%
import projectLibrary

# %% [markdown]
# **MANDELBROT SET**

# %%
Cr=0
Ci=0
zoom=0
n=1000
k=100
colormap='prism'
set = projectLibrary.Mandelbrot(Cr, Ci, zoom, n, k, colormap)

# %%
set.interactive_plot()
# Out:
# interactive(children=(FloatSlider(value=0.0, description='r coordinates', max=2.0, min=-2.0, step=0.01), Float…

# %%
Cr=-0.13
Ci=0.99
zoom=9990
n=1000
k=100
colormap='flag'
set2 = projectLibrary.Mandelbrot(Cr, Ci, zoom, n, k, colormap)

set2.calculate()
set2.plot_set()

# %%
#(modified) divergence matrix
Cr=0
Ci=0
zoom=0
n=12
k=100
colormap='flag'
set3 = projectLibrary.Mandelbrot(Cr, Ci, zoom, n, k, colormap)

print(set3.calculate())
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# **JULIA SET**

# %%
Zr=0
Zi=0
n=1000
k=100
zoom=0
Cr=-0.4
Ci=0.6
colormap='prism'

set = projectLibrary.Julia(Zr, Zi, n, k, zoom, Cr, Ci, colormap)

# %%
set.interactive_plot()
# Out:
# interactive(children=(FloatSlider(value=0.0, description='r coordinates', max=2.0, min=-2.0, step=0.01), Float…

# %%
Zr=0
Zi=0
n=1000
k=100
zoom=3000
Cr=-0.54
Ci=0.54
colormap='prism'

set2 = projectLibrary.Julia(Zr, Zi, n, k, zoom, Cr, Ci, colormap)

set2.calculate()
set2.plot_set()

# %%
Zr=0
Zi=0
n=1000
k=300
zoom=9990
Cr=0.37
Ci=0.1
colormap='flag'

set3 = projectLibrary.Julia(Zr, Zi, n, k, zoom, Cr, Ci, colormap)

set3.calculate()
set3.plot_set()
